# %%
from donatello.examples.intent_simple import load_sculpture

# %%
sculpture = load_sculpture()

# %%
sculpture.declaration
# Out:
# {'dataset': Dataset_2019_04_04_20_41,
#  'entire': False,
#  'estimator': Estimator_2019_04_04_20_41,
#  'holdout': False,
#  'measure': Measure_2019_04_04_20_41,
#  'metrics': [roc_auc_score_2019_04_04_20_41,
#   average_precision_score_2019_04_04_20_41,
#   feature_weights_2019_04_04_20_41,
#   ThresholdRates_2019_04_04_20_41],
#  'persist': <function donatello.utils.helpers.persist>,
#  'storeReferences': True,
#  'timeFormat': '%Y_%m_%d_%H_%M',
#  'validation': True,
#  'writeAttrs': ('', 'estimator')}

# %%
sculpture.fit(sculpture.dataset)
# Out:
# Cross Validation
# grid searching
# //anaconda/lib/python2.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# grid searching
# grid searching
# grid searching
# grid searching
# Sculpture_2019_04_04_20_41

# %%
ls *pkl
# Out:
# Estimator.pkl  Sculpture.pkl

# %%
sculpture.measurements.keys()
# Out:
# ['crossValidation']

# %%
sculpture.measurements.crossValidation.keys()
# Out:
# ['ThresholdRates',
#  'roc_auc_score',
#  'feature_weights',
#  'average_precision_score']

# %%
from donatello.utils import helpers
helpers.view_sk_metric(sculpture.measurements.crossValidation.average_precision_score)
# Out:
#          score
# mean  0.994730
# std   0.003318

# %%
sculpture.measurements.crossValidation.feature_weights.mean
# Out:
#                          coefficients
# names
# worst concavity             -1.258685
# worst compactness           -0.842438
# mean concavity              -0.461637
# worst concave points        -0.451061
# worst texture               -0.366692
# mean compactness            -0.277123
# worst symmetry              -0.274831
# mean concave points         -0.223502
# worst smoothness            -0.194865
# worst perimeter             -0.175581
# mean symmetry               -0.104784
# area error                  -0.098406
# mean smoothness             -0.092166
# worst fractal dimension     -0.081419
# concavity error             -0.071289
# concave points error        -0.029101
# worst area                  -0.022367
# compactness error           -0.014527
# smoothness error            -0.013091
# mean fractal dimension      -0.010277
# mean area                   -0.008286
# symmetry error              -0.004163
# fractal dimension error      0.001296
# radius error                 0.049205
# mean perimeter               0.067369
# mean texture                 0.132235
# perimeter error              0.306093
# intercept_                   0.326098
# texture error                1.198808
# worst radius                 1.410482
# mean radius                  1.553977

# %%
sculpture.measurements.crossValidation.ThresholdRates.mean.columns.tolist()
# Out:
# ['true_negative',
#  'false_positive',
#  'false_negative',
#  'true_positive',
#  'precision',
#  'recall',
#  'specificity',
#  'false_omission_rate',
#  'negative_predictive_value',
#  'f1',
#  'fall_out',
#  'false_discovery_rate']

# %%
sculpture.measurements.crossValidation.ThresholdRates.mean[['precision', 'recall']].loc[::5]
# Out:
#               precision    recall
# points
# 1.623316e-49   0.629792  1.000000
# 2.911910e-11   0.661888  1.000000
# 1.305051e-08   0.699280  1.000000
# 5.871870e-06   0.741465  1.000000
# 4.770137e-04   0.786078  1.000000
# 3.777897e-03   0.839318  1.000000
# 9.729265e-02   0.895883  0.993331
# 4.045008e-01   0.942478  0.971273
# 8.197599e-01   0.985902  0.939640
# 9.043774e-01   0.992590  0.864397
# 9.455728e-01   0.996154  0.786358
# 9.784847e-01   0.996000  0.709326
# 9.855100e-01   0.995652  0.631052
# 9.909764e-01   0.994872  0.551811
# 9.944273e-01   1.000000  0.477573
# 9.960639e-01   1.000000  0.397611
# 9.980505e-01   1.000000  0.317188
# 9.985678e-01   1.000000  0.241702
# 9.993304e-01   1.000000  0.161605
# 9.996368e-01   1.000000  0.080818
# 9.999980e-01        NaN  0.000000

# %%
for fold, (designTrain, designTest, targetTrain, targetTest) in enumerate(sculpture.dataset):
    print(fold)
    display(designTrain.head())
    display(targetTest.to_frame().head())
    print('*'*10)
# Out:
# 0
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38           122.8     1001.0          0.11840
# 1        20.57         17.77           132.9     1326.0          0.08474
# 4        20.29         14.34           135.1     1297.0          0.10030
# 6        18.25         19.98           119.6     1040.0          0.09463
# 7        13.71         20.83            90.2      577.9          0.11890
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760         0.30010              0.14710         0.2419
# 1           0.07864         0.08690              0.07017         0.1812
# 4           0.13280         0.19800              0.10430         0.1809
# 6           0.10900         0.11270              0.07400         0.1794
# 7           0.16450         0.09366              0.05985         0.2196
#
#    mean fractal dimension           ...             worst radius  \
# 0                 0.07871           ...                    25.38
# 1                 0.05667           ...                    24.99
# 4                 0.05883           ...                    22.54
# 6                 0.05742           ...                    22.88
# 7                 0.07451           ...                    17.06
#
#    worst texture  worst perimeter  worst area  worst smoothness  \
# 0          17.33            184.6      2019.0            0.1622
# 1          23.41            158.8      1956.0            0.1238
# 4          16.67            152.2      1575.0            0.1374
# 6          27.66            153.2      1606.0            0.1442
# 7          28.14            110.6       897.0            0.1654
#
#    worst compactness  worst concavity  worst concave points  worst symmetry  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 4             0.2050           0.4000                0.1625          0.2364
# 6             0.2576           0.3784                0.1932          0.3063
# 7             0.3682           0.2678                0.1556          0.3196
#
#    worst fractal dimension
# 0                  0.11890
# 1                  0.08902
# 4                  0.07678
# 6                  0.08368
# 7                  0.11510
#
# [5 rows x 30 columns]
#     is_malignant
# 2            0.0
# 3            0.0
# 5            0.0
# 17           0.0
# 22           0.0
# **********
# 1
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension           ...             worst radius  \
# 0                 0.07871           ...                    25.38
# 1                 0.05667           ...                    24.99
# 2                 0.05999           ...                    23.57
# 3                 0.09744           ...                    14.91
# 4                 0.05883           ...                    22.54
#
#    worst texture  worst perimeter  worst area  worst smoothness  \
# 0          17.33           184.60      2019.0            0.1622
# 1          23.41           158.80      1956.0            0.1238
# 2          25.53           152.50      1709.0            0.1444
# 3          26.50            98.87       567.7            0.2098
# 4          16.67           152.20      1575.0            0.1374
#
#    worst compactness  worst concavity  worst concave points  worst symmetry  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    worst fractal dimension
# 0                  0.11890
# 1                  0.08902
# 2                  0.08758
# 3                  0.17300
# 4                  0.07678
#
# [5 rows x 30 columns]
#     is_malignant
# 13           0.0
# 23           0.0
# 26           0.0
# 29           0.0
# 31           0.0
# **********
# 2
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 5        12.45         15.70           82.57      477.1          0.12780
# 6        18.25         19.98          119.60     1040.0          0.09463
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0            0.2776          0.3001              0.14710         0.2419
# 2            0.1599          0.1974              0.12790         0.2069
# 3            0.2839          0.2414              0.10520         0.2597
# 5            0.1700          0.1578              0.08089         0.2087
# 6            0.1090          0.1127              0.07400         0.1794
#
#    mean fractal dimension           ...             worst radius  \
# 0                 0.07871           ...                    25.38
# 2                 0.05999           ...                    23.57
# 3                 0.09744           ...                    14.91
# 5                 0.07613           ...                    15.47
# 6                 0.05742           ...                    22.88
#
#    worst texture  worst perimeter  worst area  worst smoothness  \
# 0          17.33           184.60      2019.0            0.1622
# 2          25.53           152.50      1709.0            0.1444
# 3          26.50            98.87       567.7            0.2098
# 5          23.75           103.40       741.6            0.1791
# 6          27.66           153.20      1606.0            0.1442
#
#    worst compactness  worst concavity  worst concave points  worst symmetry  \
# 0             0.6656           0.7119                0.2654          0.4601
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 5             0.5249           0.5355                0.1741          0.3985
# 6             0.2576           0.3784                0.1932          0.3063
#
#    worst fractal dimension
# 0                  0.11890
# 2                  0.08758
# 3                  0.17300
# 5                  0.12440
# 6                  0.08368
#
# [5 rows x 30 columns]
#     is_malignant
# 1            0.0
# 4            0.0
# 12           0.0
# 14           0.0
# 15           0.0
# **********
# 3
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
# 5        12.45         15.70           82.57      477.1          0.12780
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
# 5           0.17000          0.1578              0.08089         0.2087
#
#    mean fractal dimension           ...             worst radius  \
# 1                 0.05667           ...                    24.99
# 2                 0.05999           ...                    23.57
# 3                 0.09744           ...                    14.91
# 4                 0.05883           ...                    22.54
# 5                 0.07613           ...                    15.47
#
#    worst texture  worst perimeter  worst area  worst smoothness  \
# 1          23.41           158.80      1956.0            0.1238
# 2          25.53           152.50      1709.0            0.1444
# 3          26.50            98.87       567.7            0.2098
# 4          16.67           152.20      1575.0            0.1374
# 5          23.75           103.40       741.6            0.1791
#
#    worst compactness  worst concavity  worst concave points  worst symmetry  \
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
# 5             0.5249           0.5355                0.1741          0.3985
#
#    worst fractal dimension
# 1                  0.08902
# 2                  0.08758
# 3                  0.17300
# 4                  0.07678
# 5                  0.12440
#
# [5 rows x 30 columns]
#     is_malignant
# 0            0.0
# 6            0.0
# 9            0.0
# 10           0.0
# 18           0.0
# **********
# 4
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension           ...             worst radius  \
# 0                 0.07871           ...                    25.38
# 1                 0.05667           ...                    24.99
# 2                 0.05999           ...                    23.57
# 3                 0.09744           ...                    14.91
# 4                 0.05883           ...                    22.54
#
#    worst texture  worst perimeter  worst area  worst smoothness  \
# 0          17.33           184.60      2019.0            0.1622
# 1          23.41           158.80      1956.0            0.1238
# 2          25.53           152.50      1709.0            0.1444
# 3          26.50            98.87       567.7            0.2098
# 4          16.67           152.20      1575.0            0.1374
#
#    worst compactness  worst concavity  worst concave points  worst symmetry  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    worst fractal dimension
# 0                  0.11890
# 1                  0.08902
# 2                  0.08758
# 3                  0.17300
# 4                  0.07678
#
# [5 rows x 30 columns]
#     is_malignant
# 7            0.0
# 8            0.0
# 11           0.0
# 16           0.0
# 21           1.0
# **********

# %% [markdown]
# Note the first record is in the training set in fold 1,2,3,5 and in the evaluation set in fold 4
