# %% [markdown]
# ## Example: Scikit-learn's breast cancer binary classification

# %%
from donatello.examples.breast_cancer_simple.declaration import load_sklearn_bc_declaration

# %%
manager = load_sklearn_bc_declaration()

# %%
manager.get_params()
# Out:
# {'combiner': None,
#  'dataKwargs': {'raws':      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
#   0         17.990         10.38          122.80     1001.0          0.11840
#   1         20.570         17.77          132.90     1326.0          0.08474
#   2         19.690         21.25          130.00     1203.0          0.10960
#   3         11.420         20.38           77.58      386.1          0.14250
#   4         20.290         14.34          135.10     1297.0          0.10030
#   5         12.450         15.70           82.57      477.1          0.12780
#   6         18.250         19.98          119.60     1040.0          0.09463
#   7         13.710         20.83           90.20      577.9          0.11890
#   8         13.000         21.82           87.50      519.8          0.12730
#   9         12.460         24.04           83.97      475.9          0.11860
#   10        16.020         23.24          102.70      797.8          0.08206
# ...

# %%
manager.build()
# Out:
# /Users/markweiss/.local/lib/python2.7/site-packages/donatello-0.0.1-py2.7.egg/donatello/components/manager.py:104: UserWarning: Manager does not have a name, defaulting to class ManagerClassification
# ManagerClassification created at 2018_11_04_11_36

# %%
manager.scores.holdout.feature_weights
# Out:
#                          coefficients
# names
# worst concavity             -1.578982
# worst compactness           -1.238261
# worst symmetry              -0.679929
# worst concave points        -0.579283
# mean concavity              -0.571503
# mean compactness            -0.385358
# worst texture               -0.315021
# mean concave points         -0.283902
# worst smoothness            -0.244677
# mean symmetry               -0.224177
# mean smoothness             -0.137423
# worst fractal dimension     -0.130207
# area error                  -0.095836
# worst perimeter             -0.095670
# mean perimeter              -0.076974
# concavity error             -0.057423
# symmetry error              -0.040840
# mean fractal dimension      -0.034922
# concave points error        -0.033556
# worst area                  -0.026657
# compactness error           -0.023026
# smoothness error            -0.013320
# mean area                    0.001433
# ...

# %%
import pandas as pd
pd.Series([manager.scores.holdout.roc_auc_score.values[0][0], manager.scores.holdout.average_precision_score.values[0][0]],
          index=['roc','average_precision'], name='scores').to_frame()
# Out:
#                      scores
# roc                0.995388
# average_precision  0.997324
