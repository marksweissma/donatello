# %%
from IPython.core.display import HTML
def _print(message):
    print ''
    print '*' * 20
    if isinstance(message, str):
        print message
    else:
        for i in message:
            print '-'
            print i
    print '*' * 20
    print ''

# %%
from declaration import load_sklearn_bc_declaration

# %%
owner = load_sklearn_bc_declaration()

# %%
for name, value in owner.get_params(deep=False).items():
    if value in [None, [], {}, False]:
        continue
    else:
        _print((name, value))
# Out:
# ********************
# -
# mlType
# -
# classification
# ********************
#
#
# ********************
# -
# writeAttrs
# -
# ('', 'estimator')
# ********************
#
#
# ********************
# -
# typeDispatch
# -
# {'splitter': <class 'donatello.components.splitter.Splitter'>, 'scorer': {'regression': <class 'donatello.components.scorer.ScorerRegression'>, 'classification': <class 'donatello.components.scorer.ScorerClassification'>}, 'hook': <class 'donatello.components.hook.Local'>}
# ********************
#
#
# ********************
# -
# metrics
# -
# {'threshold_rates': defaultdict(<type 'dict'>, {'sort': 'thresholds', 'key': 'thresholds'}), 'feature_weights': defaultdict(<type 'dict'>, {'sort': 'coefficients', 'key': 'names'}), <function roc_auc_score at 0x1092557d0>: defaultdict(<type 'dict'>, {}), <function average_precision_score at 0x109255758>: defaultdict(<type 'dict'>, {})}
# ********************
#
#
# ********************
# -
# storeReferences
# -
# True
# ********************
#
#
# ********************
# -
# dataKwargs
# -
# {'queries': {None: {'querier': <function _load_sklearn_bc_dataset at 0x10978c0c8>}}}
# ********************
#
#
# ********************
# -
# estimator
# -
# Estimator_LogisticRegression created at 2018_11_27_17_40
#  ---
#  **sklearn repr**
#  ---
# Estimator(gridKwargs={'scoring': 'f1', 'cv': 5}, mlType='classification',
#      model=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#      paramGrid={'model__C': [0.01, 0.016681005372000592, 0.027825594022071243, 0.046415888336127774, 0.0774263682681127, 0.1291549665014884, 0.21544346900318834, 0.3593813663804626, 0.5994842503189409, 1.0]},
#      timeFormat='%Y_%m_%d_%H_%M',
#      transformer=Selector created at [no_init_time],
#      typeDispatch={'regression': {'score': 'score_all', 'method': 'predict'}, 'classification': {'score': 'score_first', 'method': 'predict_proba'}})
# ********************
#
#
# ********************
# -
# timeFormat
# -
# %Y_%m_%d_%H_%M
# ********************
#
#
# ********************
# -
# holdOut
# -
# True
# ********************
#
#
# ********************
# -
# validation
# -
# True
# ********************
#
#
# ********************
# -
# splitterKwargs
# -
# {'target': 'is_malignant'}
# ********************

# %%
owner.fit()
# Out:
# -----------------------------------------------------------
# AttributeError            Traceback (most recent call last)
# <ipython-input-6-adc5460de47e> in <module>()
# ----> 1 owner.fit()
#
# /Users/markweiss/code/donatello/components/data.pyc in package_data(wrapped, instance, args, kwargs)
#     117         mlType = getattr(instance, '_mlType', None)
#     118         data = Data(X=X, y=y, mlType=mlType)
# --> 119     if not data.hasContents and data.queries:
#     120         data.execute_queries(data.queries)
#     121
#
# /Users/markweiss/code/donatello/components/data.pyc in hasContents(self)
#      58     @property
#      59     def hasContents(self):
# ---> 60         if isinstance(self.contents, dict):
#      61             state = self.contents != {}
#      62         else:
#
# /Users/markweiss/code/donatello/components/data.pyc in contents(self)
#      47         if value is None:
#      48             if self.copyRaws:
# ---> 49                 value = self.raws.copy()
#      50             else:
#      51                 value = self.raws
#
# AttributeError: 'NoneType' object has no attribute 'copy'

# %%
# %debug
# Out:
# > /Users/markweiss/code/donatello/components/data.py(49)contents()
#      47         if value is None:
#      48             if self.copyRaws:
# ---> 49                 value = self.raws.copy()
#      50             else:
#      51                 value = self.raws
#
# ipdb> dir()
# ['self', 'value']
# ipdb> self
# Data created at 2018_11_27_17_40
# ipdb> value

# %%
for metric, value in owner.scores.crossValidation.items():
    if value.shape[0] > 50:
        _print((metric, value.iloc[::5]))
    else:
        _print((metric, value))
# Out:
# ********************
# -
# roc_auc_score
# -
#       score
# _
# 1  0.982545
# ********************
#
#
# ********************
# -
# feature_weights
# -
#                          coefficients
# names
# worst concavity             -1.126453
# worst compactness           -0.884533
# worst symmetry              -0.457216
# mean concavity              -0.414262
# worst concave points        -0.396943
# mean compactness            -0.286178
# worst texture               -0.273814
# mean concave points         -0.196709
# worst smoothness            -0.161054
# worst perimeter             -0.160103
# mean symmetry               -0.149295
# worst fractal dimension     -0.094073
# mean smoothness             -0.089900
# area error                  -0.087825
# concavity error             -0.066980
# compactness error           -0.038705
# symmetry error              -0.034293
# concave points error        -0.026423
# mean fractal dimension      -0.026101
# worst area                  -0.023186
# smoothness error            -0.010760
# mean area                   -0.003113
# fractal dimension error     -0.002446
# radius error                 0.017186
# mean texture                 0.087225
# mean perimeter               0.090673
# perimeter error              0.183725
# intercept_                   0.250962
# texture error                0.762710
# worst radius                 1.044482
# mean radius                  1.447336
# ********************
#
#
# ********************
# -
# average_precision_score
# -
#       score
# _
# 1  0.986379
# ********************
#
#
# ********************
# -
# threshold_rates
# -
#               true_negative  false_positive  false_negative  true_positive  \
# thresholds
# 2.877667e-32       0.000078        0.049298        0.000000       0.014594
# 5.523955e-11       0.001712        0.042746        0.000000       0.014594
# 7.129674e-08       0.003345        0.036193        0.000000       0.014594
# 1.529868e-05       0.004979        0.029641        0.000000       0.014594
# 5.422083e-04       0.006691        0.022777        0.000000       0.014594
# 1.107341e-02       0.008324        0.016225        0.000000       0.014594
# 9.317835e-02       0.009802        0.010296        0.000231       0.014485
# 3.619730e-01       0.010969        0.005616        0.000923       0.014157
# 7.780334e-01       0.011903        0.001872        0.002076       0.013610
# 8.932807e-01       0.012136        0.000936        0.004151       0.012626
# 9.444423e-01       0.012136        0.000936        0.006573       0.011479
# 9.671575e-01       0.012214        0.000624        0.008879       0.010385
# 9.802066e-01       0.012214        0.000624        0.011416       0.009183
# 9.877782e-01       0.012214        0.000624        0.013838       0.008035
# 9.919019e-01       0.012214        0.000624        0.016259       0.006887
# 9.948628e-01       0.012214        0.000624        0.018681       0.005739
# 9.966729e-01       0.012292        0.000312        0.021102       0.004591
# 9.978050e-01       0.012292        0.000312        0.023524       0.003444
# 9.985960e-01       0.012292        0.000312        0.025946       0.002296
# 9.992649e-01       0.012370        0.000000        0.028252       0.001203
# 9.998829e-01       0.012370        0.000000        0.030789       0.000000
#
#               false_omission_rate        f1  sensitivity  specificity  \
